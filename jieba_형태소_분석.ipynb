# %% [markdown]
# <a href="https://colab.research.google.com/github/dadadacole/Comparing-BTS--BILIBILI-and-YOUTUBE--comments/blob/main/jieba_%ED%98%95%ED%83%9C%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경 준비

# %%
# jieba 설치하기
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.6/dist-packages (0.42.1)

# %%
# jieba 실행하기
import jieba
## pandas을 실행하기, 단 실행 별명을 pd로
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
# 구글 드라이브 연결을 위한 기본 세팅 
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## 문서 ID로 실제 파일 불러오기
# 실습을 위한 중국 역대 신년사 1992-2020
## https://drive.google.com/file/d/18TnFdgMoVVT5EIs7aAX1NYF7sNRIeRkN/view?usp=sharing

rawdata_downloaded = drive.CreateFile({'id': '18TnFdgMoVVT5EIs7aAX1NYF7sNRIeRkN'})
rawdata_downloaded.GetContentFile('rawdata.tsv')

# %%
# "rawdata.tsv" 파일의 내용을 "원본데이터" 변수로 불러오기
원본데이터 = pd.read_csv('rawdata.tsv' )

# %%
# "원본데이터" 변수 내용 확인하기
원본데이터
# Out:
#        BILIBILI         아이디  ... Unnamed: 5 Unnamed: 6
# 0      BILIBILI   此账号尚未设置ID  ...        0.0        0.0
# 1      BILIBILI  草莓味_cheese  ...        0.0        0.0
# 2      BILIBILI     教母not酵母  ...        0.0        0.0
# 3      BILIBILI        秋月eS  ...        5.0        3.0
# 4      BILIBILI     万家灯火应长安  ...        0.0        0.0
# ...         ...         ...  ...        ...        ...
# 10377  BILIBILI        泠泠沫玥  ...        2.0        0.0
# 10378  BILIBILI  圣诞节会不开心的小猪  ...        1.0        0.0
# 10379  BILIBILI      田国香香子的  ...      863.0        2.0
# 10380  BILIBILI     -果兔酿蜜酒-  ...        2.0        0.0
# 10381  BILIBILI   Niniibaby  ...        0.0        0.0
#
# [10382 rows x 7 columns]

# %% [markdown]
# # 형태소 분석

# %%
# jieba(중국어형태소분석기) 중 품사태깅 요소를 pseg 별명으로 실행하기
import jieba
import jieba.posseg as pseg

# %%
# "원본데이터"를 대상으로 "jieba"를 사용해서 형태소 분석하기
저장공간  = [] ## 모든 결과를 저장할 빈 공간으로 "저장공간" 설정
for index, row in 원본데이터.iterrows():# 원본데이터의 컬럼(열)을 불러와서 반복할 준비!
    textdata = row[4]  # 분석에서 사용할 텍스트 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    type = row[0]  # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    형태소 = pseg.cut(textdata)  # jieba의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
    for word in 형태소:  # jieba로 도출된 개별 형태소에 추가 정보를 기입하기 위해서 반복해준다.
      형태소종합 = [word.word,word.flag,type,1]  # 형태소종합에 분류정보와 카운트정보를 추가한다.
      저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-93706996b4aa> in <module>()
#       5     type = row[0]  # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
#       6     형태소 = pseg.cut(textdata)  # jieba의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
# ----> 7     for word in 형태소:  # jieba로 도출된 개별 형태소에 추가 정보를 기입하기 위해서 반복해준다.
#       8       형태소종합 = [word.word,word.flag,type,1]  # 형태소종합에 분류정보와 카운트정보를 추가한다.
#       9       저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.
#
# /usr/local/lib/python3.6/dist-packages/jieba/posseg/__init__.py in cut(sentence, HMM, use_paddle)
#     292     global dt
#     293     if jieba.pool is None:
# --> 294         for w in dt.cut(sentence, HMM=HMM):
#     295             yield w
#     296     else:
#
# /usr/local/lib/python3.6/dist-packages/jieba/posseg/__init__.py in cut(self, sentence, HMM)
#     247
#     248     def cut(self, sentence, HMM=True):
# --> 249         for w in self.__cut_internal(sentence, HMM=HMM):
#     250             yield w
#     251
#
# /usr/local/lib/python3.6/dist-packages/jieba/posseg/__init__.py in __cut_internal(self, sentence, HMM)
#     215     def __cut_internal(self, sentence, HMM=True):
#     216         self.makesure_userdict_loaded()
# --> 217         sentence = strdecode(sentence)
#     218         blocks = re_han_internal.split(sentence)
#     219         if HMM:
#
# /usr/local/lib/python3.6/dist-packages/jieba/_compat.py in strdecode(sentence)
#      77     if not isinstance(sentence, text_type):
#      78         try:
# ---> 79             sentence = sentence.decode('utf-8')
#      80         except UnicodeDecodeError:
#      81             sentence = sentence.decode('gbk', 'ignore')
#
# AttributeError: 'float' object has no attribute 'decode'

# %%
# "형태소" 변수의 저장 내용 확인
형태소
# Out:
# <generator object cut at 0x7fbbeedd2c50>

# %%
# "형태소종합" 변수의 저장 내용 확인
형태소종합
# Out:
# ['\u202c', 'x', 'BILIBILI', 1]

# %%
# "저장공간" 변수의 저장 내용 확인
저장공간
# Out:
# [['立场', 'n', 'BILIBILI', 1],
#  ['不同', 'a', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['没错', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['但是', 'c', 'BILIBILI', 1],
#  ['希望', 'v', 'BILIBILI', 1],
#  ['中国', 'ns', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['自重', 'a', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['又', 'd', 'BILIBILI', 1],
#  ['火', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['b', 'eng', 'BILIBILI', 1],
#  ['站', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['和微博', 'nr', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['虾', 'n', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['一', 'm', 'BILIBILI', 1],
#  ['拼', 'v', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['辣', 'n', 'BILIBILI', 1],
#  ['眼睛', 'n', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['来', 'v', 'BILIBILI', 1],
#  ['道', 'q', 'BILIBILI', 1],
#  ['个', 'q', 'BILIBILI', 1],
#  ['歉', 'ng', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['照样', 'd', 'BILIBILI', 1],
#  ['给', 'p', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['送', 'v', 'BILIBILI', 1],
#  ['钱', 'n', 'BILIBILI', 1],
#  ['看', 'v', 'BILIBILI', 1],
#  ['完', 'v', 'BILIBILI', 1],
#  ['金刚', 'nr', 'BILIBILI', 1],
#  ['川', 'j', 'BILIBILI', 1],
#  ['再', 'd', 'BILIBILI', 1],
#  ['回来', 'v', 'BILIBILI', 1],
#  ['看看', 'v', 'BILIBILI', 1],
#  ['这', 'r', 'BILIBILI', 1],
#  ['几个', 'm', 'BILIBILI', 1],
#  ['逼', 'v', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['微笑', 'vn', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['啥', 'r', 'BILIBILI', 1],
#  ['苟', 'd', 'BILIBILI', 1],
#  ['团体', 'n', 'BILIBILI', 1],
#  ['还有', 'v', 'BILIBILI', 1],
#  ['人粉', 'n', 'BILIBILI', 1],
#  ['服', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['服', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['https', 'eng', 'BILIBILI', 1],
#  [':', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['space', 'eng', 'BILIBILI', 1],
#  ['.', 'm', 'BILIBILI', 1],
#  ['bilibili', 'eng', 'BILIBILI', 1],
#  ['.', 'm', 'BILIBILI', 1],
#  ['com', 'eng', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['15201286', 'm', 'BILIBILI', 1],
#  ['?', 'x', 'BILIBILI', 1],
#  ['share', 'eng', 'BILIBILI', 1],
#  ['_', 'x', 'BILIBILI', 1],
#  ['medium', 'eng', 'BILIBILI', 1],
#  ['=', 'x', 'BILIBILI', 1],
#  ['android', 'eng', 'BILIBILI', 1],
#  ['&', 'x', 'BILIBILI', 1],
#  ['amp', 'eng', 'BILIBILI', 1],
#  [';', 'x', 'BILIBILI', 1],
#  ['share', 'eng', 'BILIBILI', 1],
#  ['_', 'x', 'BILIBILI', 1],
#  ['source', 'eng', 'BILIBILI', 1],
#  ['=', 'x', 'BILIBILI', 1],
#  ['copy', 'eng', 'BILIBILI', 1],
#  ['_', 'x', 'BILIBILI', 1],
#  ['link', 'eng', 'BILIBILI', 1],
#  ['&', 'x', 'BILIBILI', 1],
#  ['amp', 'eng', 'BILIBILI', 1],
#  [';', 'x', 'BILIBILI', 1],
#  ['bbid', 'eng', 'BILIBILI', 1],
#  ['=', 'x', 'BILIBILI', 1],
#  ['XY1BBFB1F57AD9FA4B5DBBC741FBA9134D337', 'eng', 'BILIBILI', 1],
#  ['&', 'x', 'BILIBILI', 1],
#  ['amp', 'eng', 'BILIBILI', 1],
#  [';', 'x', 'BILIBILI', 1],
#  ['ts', 'eng', 'BILIBILI', 1],
#  ['=', 'x', 'BILIBILI', 1],
#  ['1605990719600', 'm', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['屏蔽', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['追星', 'n', 'BILIBILI', 1],
#  ['前', 'f', 'BILIBILI', 1],
#  ['做', 'v', 'BILIBILI', 1],
#  ['个人', 'n', 'BILIBILI', 1],
#  ['吧', 'y', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['看看', 'v', 'BILIBILI', 1],
#  ['新歌', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['评论', 'n', 'BILIBILI', 1],
#  ['吧', 'y', 'BILIBILI', 1],
#  ['https', 'eng', 'BILIBILI', 1],
#  [':', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['www', 'eng', 'BILIBILI', 1],
#  ['.', 'm', 'BILIBILI', 1],
#  ['bilibili', 'eng', 'BILIBILI', 1],
#  ['.', 'm', 'BILIBILI', 1],
#  ['com', 'eng', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['video', 'eng', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['BV1oK4y1f7SG', 'eng', 'BILIBILI', 1],
#  ['恶心', 'n', 'BILIBILI', 1],
#  ['套团', 'n', 'BILIBILI', 1],
#  ['套团', 'n', 'BILIBILI', 1],
#  ['糊糊', 'a', 'BILIBILI', 1],
#  ['糊', 'a', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['团粉', 'n', 'BILIBILI', 1],
#  ['真的', 'd', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['恶心', 'n', 'BILIBILI', 1],
#  ['好笑', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['过', 'ug', 'BILIBILI', 1],
#  ['几天', 'm', 'BILIBILI', 1],
#  ['你们', 'r', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['忘记', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['然后', 'c', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['屁团', 'n', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['更火', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['其实', 'd', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['这', 'r', 'BILIBILI', 1],
#  ['之后', 'f', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['才', 'd', 'BILIBILI', 1],
#  ['觉得', 'v', 'BILIBILI', 1],
#  ['卢本伟', 'nr', 'BILIBILI', 1],
#  ['其实', 'd', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['还是', 'c', 'BILIBILI', 1],
#  ['挺', 'd', 'BILIBILI', 1],
#  ['好', 'a', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['doge', 'eng', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['doge', 'eng', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['佛', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['又', 'd', 'BILIBILI', 1],
#  ['有人', 'r', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['b', 'eng', 'BILIBILI', 1],
#  ['站上', 's', 'BILIBILI', 1],
#  ['发', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['还有', 'v', 'BILIBILI', 1],
#  ['一堆', 'm', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['搁', 'v', 'BILIBILI', 1],
#  ['哪', 'r', 'BILIBILI', 1],
#  ['洗', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['上', 'f', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['热门', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['离谱', 'n', 'BILIBILI', 1],
#  ['草', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['今天下午', 'nr', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['同学', 'n', 'BILIBILI', 1],
#  ['才', 'd', 'BILIBILI', 1],
#  ['跟', 'p', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['说', 'v', 'BILIBILI', 1],
#  ['什么', 'r', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['少年', 'm', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['回归', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['很', 'zg', 'BILIBILI', 1],
#  ['激动', 'a', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['踏马', 'v', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['知道', 'v', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['少年', 'm', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['个', 'q', 'BILIBILI', 1],
#  ['啥', 'r', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['一', 'm', 'BILIBILI', 1],
#  ['上来', 't', 'BILIBILI', 1],
#  ['搜', 'v', 'BILIBILI', 1],
#  ['又', 'd', 'BILIBILI', 1],
#  ['跳出', 'v', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['东西', 'ns', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['饭圈', 'n', 'BILIBILI', 1],
#  ['真', 'd', 'BILIBILI', 1],
#  ['恶心', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['这样', 'r', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['能', 'v', 'BILIBILI', 1],
#  ['粉', 'n', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['洗', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['真快', 'd', 'BILIBILI', 1],
#  ['https', 'eng', 'BILIBILI', 1],
#  [':', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['b23', 'eng', 'BILIBILI', 1],
#  ['.', 'm', 'BILIBILI', 1],
#  ['tv', 'eng', 'BILIBILI', 1],
#  ['/', 'x', 'BILIBILI', 1],
#  ['av970307740', 'eng', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['恶臭', 'a', 'BILIBILI', 1],
#  ['账号', 'n', 'BILIBILI', 1],
#  ['又', 'd', 'BILIBILI', 1],
#  ['再', 'd', 'BILIBILI', 1],
#  ['发', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['BV1wp4y1r7PW', 'eng', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['回来', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['😅', 'x', 'BILIBILI', 1],
#  ['😅', 'x', 'BILIBILI', 1],
#  ['😅', 'x', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['得', 'ud', 'BILIBILI', 1],
#  ['顶一下', 'd', 'BILIBILI', 1],
#  ['说实话', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['家', 'q', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['真的', 'd', 'BILIBILI', 1],
#  ['很', 'zg', 'BILIBILI', 1],
#  ['恶臭', 'a', 'BILIBILI', 1],
#  ['害', 'v', 'BILIBILI', 1],
#  ['这群人', 'l', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['只是', 'c', 'BILIBILI', 1],
#  ['被', 'p', 'BILIBILI', 1],
#  ['操控', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['可怜', 'v', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['罢了', 'y', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['和', 'c', 'BILIBILI', 1],
#  ['一个', 'm', 'BILIBILI', 1],
#  ['傀儡', 'n', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['啥', 'r', 'BILIBILI', 1],
#  ['好气', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['好多', 'm', 'BILIBILI', 1],
#  ['老师', 'n', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['带', 'v', 'BILIBILI', 1],
#  ['着', 'uz', 'BILIBILI', 1],
#  ['学生', 'n', 'BILIBILI', 1],
#  ['追星', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['整治', 'n', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['离谱', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['而且', 'c', 'BILIBILI', 1],
#  ['所谓', 'b', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['鲜肉', 'n', 'BILIBILI', 1],
#  ['往后', 't', 'BILIBILI', 1],
#  ['稍稍', 'd', 'BILIBILI', 1],
#  ['吧', 'y', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['啥时候', 'r', 'BILIBILI', 1],
#  ['贫弱', 'a', 'BILIBILI', 1],
#  ['成', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['帅气', 'n', 'BILIBILI', 1],
#  ['酷', 'd', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['代表', 'n', 'BILIBILI', 1],
#  ['词', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['晦气', 'an', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  ['这家', 'r', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['成', 'v', 'BILIBILI', 1],
#  ['大众', 'n', 'BILIBILI', 1],
#  ['雷点', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['可笑', 'v', 'BILIBILI', 1],
#  ['死', 'v', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['这件', 'mq', 'BILIBILI', 1],
#  ['事', 'n', 'BILIBILI', 1],
#  ['到底', 'd', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['针对', 'p', 'BILIBILI', 1],
#  ['于', 'p', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['少年', 'm', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['呢', 'y', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['还是', 'c', 'BILIBILI', 1],
#  ['中国', 'ns', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['呢', 'y', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['疑惑', 'v', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['啊', 'zg', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['就是', 'd', 'BILIBILI', 1],
#  ['来', 'v', 'BILIBILI', 1],
#  ['圈钱', 'n', 'BILIBILI', 1],
#  ['来', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['呗', 'y', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  ['“', 'x', 'BILIBILI', 1],
#  ['限', 'v', 'BILIBILI', 1],
#  ['韩令', 'nr', 'BILIBILI', 1],
#  ['”', 'x', 'BILIBILI', 1],
#  ['松', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['不是', 'c', 'BILIBILI', 1],
#  ['队长', 'n', 'BILIBILI', 1],
#  ['说', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['吗', 'y', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['为什么', 'r', 'BILIBILI', 1],
#  ['骂', 'v', 'BILIBILI', 1],
#  ['全团', 'n', 'BILIBILI', 1],
#  ['？', 'x', 'BILIBILI', 1],
#  ['(', 'x', 'BILIBILI', 1],
#  ['没有', 'v', 'BILIBILI', 1],
#  ['恶意', 'v', 'BILIBILI', 1],
#  ['只是', 'c', 'BILIBILI', 1],
#  ['好奇', 'a', 'BILIBILI', 1],
#  [')', 'x', 'BILIBILI', 1],
#  ['BV1yb411y76d', 'eng', 'BILIBILI', 1],
#  ['一点', 'm', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['影响', 'vn', 'BILIBILI', 1],
#  ['啊', 'zg', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['网络', 'n', 'BILIBILI', 1],
#  ['圈子', 'n', 'BILIBILI', 1],
#  ['群体', 'n', 'BILIBILI', 1],
#  ['好像', 'v', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['新', 'a', 'BILIBILI', 1],
#  ['航路', 'n', 'BILIBILI', 1],
#  ['开辟', 'v', 'BILIBILI', 1],
#  ['之前', 'f', 'BILIBILI', 1],
#  ['互相', 'd', 'BILIBILI', 1],
#  ['隔绝', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['人类', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['这边', 'r', 'BILIBILI', 1],
#  ['骂', 'v', 'BILIBILI', 1],
#  ['得', 'ud', 'BILIBILI', 1],
#  ['欢', 'a', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['那边', 'r', 'BILIBILI', 1],
#  ['快乐', 'a', 'BILIBILI', 1],
#  ['追星', 'n', 'BILIBILI', 1],
#  ['能', 'v', 'BILIBILI', 1],
#  ['防得', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['东风', 'n', 'BILIBILI', 1],
#  ['导弹', 'n', 'BILIBILI', 1],
#  ['吗', 'y', 'BILIBILI', 1],
#  ['凑', 'v', 'BILIBILI', 1],
#  ['弟弟', 'n', 'BILIBILI', 1],
#  ['们', 'k', 'BILIBILI', 1],
#  ['“', 'x', 'BILIBILI', 1],
#  ['纸老虎', 'n', 'BILIBILI', 1],
#  ['从', 'p', 'BILIBILI', 1],
#  ['白眼狼', 'nr', 'BILIBILI', 1],
#  ['口中', 's', 'BILIBILI', 1],
#  ['救下', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['一条', 'm', 'BILIBILI', 1],
#  ['看门', 'v', 'BILIBILI', 1],
#  ['犬', 'ng', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['我们', 'r', 'BILIBILI', 1],
#  ['从', 'p', 'BILIBILI', 1],
#  ['纸老虎', 'n', 'BILIBILI', 1],
#  ['口中', 's', 'BILIBILI', 1],
#  ['救下', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['一条', 'm', 'BILIBILI', 1],
#  ['白眼狼', 'nr', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['”', 'x', 'BILIBILI', 1],
#  ['行', 'v', 'BILIBILI', 1],
#  ['呗', 'y', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['又', 'd', 'BILIBILI', 1],
#  ['开始', 'v', 'BILIBILI', 1],
#  ['控评', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['和', 'c', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['对', 'p', 'BILIBILI', 1],
#  ['线', 'n', 'BILIBILI', 1],
#  ['真的', 'd', 'BILIBILI', 1],
#  ['很爽', 'a', 'BILIBILI', 1],
#  ['有些', 'r', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['脱', 'v', 'BILIBILI', 1],
#  ['粉', 'n', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['不脱', 'v', 'BILIBILI', 1],
#  ['呗', 'y', 'BILIBILI', 1],
#  ['（', 'x', 'BILIBILI', 1],
#  ['只要', 'c', 'BILIBILI', 1],
#  ['能', 'v', 'BILIBILI', 1],
#  ['接受', 'v', 'BILIBILI', 1],
#  ['其他人', 'rr', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['负面', 'n', 'BILIBILI', 1],
#  ['看法', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['那', 'r', 'BILIBILI', 1],
#  ['无所谓', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['大家', 'n', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['不能', 'v', 'BILIBILI', 1],
#  ['给', 'p', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['洗脑', 'n', 'BILIBILI', 1],
#  ['）', 'x', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['但是', 'c', 'BILIBILI', 1],
#  ['扭曲', 'v', 'BILIBILI', 1],
#  ['国家', 'n', 'BILIBILI', 1],
#  ['历史', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['站', 'v', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['韩国', 'ns', 'BILIBILI', 1],
#  ['立场', 'n', 'BILIBILI', 1],
#  ['说话', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['不管', 'c', 'BILIBILI', 1],
#  ['自己', 'r', 'BILIBILI', 1],
#  ['中国', 'ns', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['立场', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['让', 'v', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['很', 'd', 'BILIBILI', 1],
#  ['无', 'v', 'BILIBILI', 1],
#  ['语', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['以', 'p', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['为', 'p', 'BILIBILI', 1],
#  ['自己', 'r', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['偶像', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['呵', 'y', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['捧', 'v', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['才', 'd', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['偶像', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['不然', 'c', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['以为', 'c', 'BILIBILI', 1],
#  ['自己', 'r', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['个', 'q', 'BILIBILI', 1],
#  ['什么', 'r', 'BILIBILI', 1],
#  ['东西', 'ns', 'BILIBILI', 1],
#  ['你家', 'r', 'BILIBILI', 1],
#  ['小孩', 'n', 'BILIBILI', 1],
#  ['糊糊', 'a', 'BILIBILI', 1],
#  ['么', 'nr', 'BILIBILI', 1],
#  ['么', 'nr', 'BILIBILI', 1],
#  ['真的', 'd', 'BILIBILI', 1],
#  ['无', 'v', 'BILIBILI', 1],
#  ['语', 'ng', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['还有', 'v', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['那', 'r', 'BILIBILI', 1],
#  ['洗', 'v', 'BILIBILI', 1],
#  ['呢', 'y', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['口味', 'n', 'BILIBILI', 1],
#  ['真', 'd', 'BILIBILI', 1],
#  ['重', 'a', 'BILIBILI', 1],
#  ['#', 'x', 'BILIBILI', 1],
#  ['KiyoTrou', 'eng', 'BILIBILI', 1],
#  ['被', 'p', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['少年', 'm', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['强奸', 'n', 'BILIBILI', 1],
#  ['已', 'd', 'BILIBILI', 1],
#  ['堕胎', 'v', 'BILIBILI', 1],
#  ['#', 'x', 'BILIBILI', 1],
#  ['搜', 'zg', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['第一个', 'm', 'BILIBILI', 1],
#  ['就是', 'd', 'BILIBILI', 1],
#  ['这个', 'r', 'BILIBILI', 1],
#  ['视频', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['\n', 'x', 'BILIBILI', 1],
#  ['顶上去', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['让', 'v', 'BILIBILI', 1],
#  ['韩国', 'ns', 'BILIBILI', 1],
#  ['母', 'b', 'BILIBILI', 1],
#  ['蛆粉', 'n', 'BILIBILI', 1],
#  ['看看', 'v', 'BILIBILI', 1],
#  ['网易', 'n', 'BILIBILI', 1],
#  ['云', 'n', 'BILIBILI', 1],
#  ['上', 'f', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['一堆', 'm', 'BILIBILI', 1],
#  ['孝子', 'n', 'BILIBILI', 1],
#  ['真的', 'd', 'BILIBILI', 1],
#  ['恶心', 'n', 'BILIBILI', 1],
#  ['到', 'v', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['捂', 'v', 'BILIBILI', 1],
#  ['脸', 'n', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['萨德', 'nr', 'BILIBILI', 1],
#  ['少年', 'm', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['看到', 'v', 'BILIBILI', 1],
#  ['有人', 'r', 'BILIBILI', 1],
#  ['点', 'm', 'BILIBILI', 1],
#  ['赞', 'v', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['再', 'd', 'BILIBILI', 1],
#  ['回来', 'v', 'BILIBILI', 1],
#  ['骂', 'v', 'BILIBILI', 1],
#  ['一句', 'm', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['邪教', 'n', 'BILIBILI', 1],
#  ['团糊', 'a', 'BILIBILI', 1],
#  ['穿', 'v', 'BILIBILI', 1],
#  ['地心', 'n', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['呲', 'v', 'BILIBILI', 1],
#  ['牙', 'n', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['#', 'x', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['为', 'p', 'BILIBILI', 1],
#  ['所有', 'b', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['和', 'c', 'BILIBILI', 1],
#  ['肖战', 'nr', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['精神状态', 'n', 'BILIBILI', 1],
#  ['感到', 'v', 'BILIBILI', 1],
#  ['担忧', 'v', 'BILIBILI', 1],
#  ['#', 'x', 'BILIBILI', 1],
#  ['啊', 'y', 'BILIBILI', 1],
#  ['这', 'r', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['他们', 'r', 'BILIBILI', 1],
#  ['颠倒', 'v', 'BILIBILI', 1],
#  ['历史', 'n', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['已经', 'd', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['人尽皆知', 'i', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['事', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['么', 'y', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['况且', 'c', 'BILIBILI', 1],
#  ['一个', 'm', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['做错事', 'v', 'BILIBILI', 1],
#  ['被', 'p', 'BILIBILI', 1],
#  ['批评', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['和', 'c', 'BILIBILI', 1],
#  ['他', 'r', 'BILIBILI', 1],
#  ['做好事', 'n', 'BILIBILI', 1],
#  ['被', 'p', 'BILIBILI', 1],
#  ['夸奖', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['二者', 'n', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['必然联系', 'l', 'BILIBILI', 1],
#  ['吗', 'y', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['看到', 'v', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['微', 'a', 'BILIBILI', 1],
#  ['博', 'n', 'BILIBILI', 1],
#  ['、', 'x', 'BILIBILI', 1],
#  ['豆瓣', 'n', 'BILIBILI', 1],
#  ['还有', 'v', 'BILIBILI', 1],
#  ['好多', 'm', 'BILIBILI', 1],
#  ['FD', 'eng', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['活跃', 'vn', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['想起', 'v', 'BILIBILI', 1],
#  ['那些', 'r', 'BILIBILI', 1],
#  ['痛苦', 'an', 'BILIBILI', 1],
#  ['地', 'uv', 'BILIBILI', 1],
#  ['牺牲', 'v', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['范', 'n', 'BILIBILI', 1],
#  ['弗利', 'nrt', 'BILIBILI', 1],
#  ['特', 'd', 'BILIBILI', 1],
#  ['攻击', 'v', 'BILIBILI', 1],
#  ['中', 'f', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['志愿军', 'n', 'BILIBILI', 1],
#  ['战士', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['心里', 's', 'BILIBILI', 1],
#  ['真是', 'd', 'BILIBILI', 1],
#  ['不好受', 'a', 'BILIBILI', 1],
#  ['…', 'x', 'BILIBILI', 1],
#  ['辣鸡', 'n', 'BILIBILI', 1],
#  ['怎么办', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['班上', 's', 'BILIBILI', 1],
#  ['有个', 'r', 'BILIBILI', 1],
#  ['防弹', 'v', 'BILIBILI', 1],
#  ['孝子', 'n', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['时间', 'n', 'BILIBILI', 1],
#  ['洗', 'v', 'BILIBILI', 1],
#  ['不如', 'c', 'BILIBILI', 1],
#  ['把', 'p', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['推', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['歌', 'n', 'BILIBILI', 1],
#  ['底下', 'f', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['同人', 'n', 'BILIBILI', 1],
#  ['台词', 'n', 'BILIBILI', 1],
#  ['给', 'p', 'BILIBILI', 1],
#  ['删', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['她', 'r', 'BILIBILI', 1],
#  ['和', 'c', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['团', 'n', 'BILIBILI', 1],
#  ['没有', 'v', 'BILIBILI', 1],
#  ['任何', 'r', 'BILIBILI', 1],
#  ['关系', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['能', 'v', 'BILIBILI', 1],
#  ['不能', 'v', 'BILIBILI', 1],
#  ['饶', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['她', 'r', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['呲', 'v', 'BILIBILI', 1],
#  ['牙', 'n', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['以史为鉴', 'i', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['面向未来', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['珍爱', 'a', 'BILIBILI', 1],
#  ['和平', 'nz', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['友好', 'a', 'BILIBILI', 1],
#  ['发展', 'vn', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['外交部', 'nt', 'BILIBILI', 1],
#  ['明确', 'ad', 'BILIBILI', 1],
#  ['说明', 'v', 'BILIBILI', 1],
#  ['“', 'x', 'BILIBILI', 1],
#  ['不要', 'df', 'BILIBILI', 1],
#  ['随之', 'p', 'BILIBILI', 1],
#  ['起舞', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['希望', 'v', 'BILIBILI', 1],
#  ['在', 'p', 'BILIBILI', 1],
#  ['看到', 'v', 'BILIBILI', 1],
#  ['媒体报道', 'n', 'BILIBILI', 1],
#  ['相关', 'v', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['切实', 'ad', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['评论', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['”', 'x', 'BILIBILI', 1],
#  ['\n', 'x', 'BILIBILI', 1],
#  ['造谣', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['人们', 'n', 'BILIBILI', 1],
#  ['该', 'r', 'BILIBILI', 1],
#  ['停下', 'v', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['停下', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['作为', 'v', 'BILIBILI', 1],
#  ['中国', 'ns', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['不要', 'df', 'BILIBILI', 1],
#  ['借着', 'p', 'BILIBILI', 1],
#  ['“', 'x', 'BILIBILI', 1],
#  ['爱国', 'ns', 'BILIBILI', 1],
#  ['正义', 'n', 'BILIBILI', 1],
#  ['”', 'x', 'BILIBILI', 1],
#  ['挑拨', 'v', 'BILIBILI', 1],
#  ['中国', 'ns', 'BILIBILI', 1],
#  ['与', 'p', 'BILIBILI', 1],
#  ['外国', 'ns', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['社交', 'n', 'BILIBILI', 1],
#  ['关系', 'n', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  ['跟风', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['路人', 'n', 'BILIBILI', 1],
#  ['朋友', 'n', 'BILIBILI', 1],
#  ['们', 'k', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['不是', 'c', 'BILIBILI', 1],
#  ['小孩子', 'n', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['舆论', 'n', 'BILIBILI', 1],
#  ['真真假假', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['既然', 'c', 'BILIBILI', 1],
#  ['知', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['回应', 'v', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['出来', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['怎么', 'r', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['看', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['呢', 'y', 'BILIBILI', 1],
#  ['。', 'x', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  ['黑粉', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  [' ', 'x', 'BILIBILI', 1],
#  ['就', 'd', 'BILIBILI', 1],
#  ['当', 'p', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['没', 'd', 'BILIBILI', 1],
#  ['说', 'v', 'BILIBILI', 1],
#  ['了', 'ul', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['观念', 'n', 'BILIBILI', 1],
#  ['不同', 'a', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['没', 'd', 'BILIBILI', 1],
#  ['办法', 'n', 'BILIBILI', 1],
#  ['组织', 'v', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['行为', 'v', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['但', 'c', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['也', 'd', 'BILIBILI', 1],
#  ['没有', 'v', 'BILIBILI', 1],
#  ['权利', 'n', 'BILIBILI', 1],
#  ['来', 'v', 'BILIBILI', 1],
#  ['指责', 'v', 'BILIBILI', 1],
#  ['任何', 'r', 'BILIBILI', 1],
#  ['与', 'p', 'BILIBILI', 1],
#  ['你', 'r', 'BILIBILI', 1],
#  ['不', 'd', 'BILIBILI', 1],
#  ['涉及', 'v', 'BILIBILI', 1],
#  ['利益', 'n', 'BILIBILI', 1],
#  ['关系', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['\n', 'x', 'BILIBILI', 1],
#  ['我们', 'r', 'BILIBILI', 1],
#  ['堂堂正正', 'i', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['中国外交部', 'nt', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['立场', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['自始至终', 'l', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['和平', 'nz', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['都', 'd', 'BILIBILI', 1],
#  ['睁开眼', 'n', 'BILIBILI', 1],
#  ['看看', 'v', 'BILIBILI', 1],
#  ['正确', 'ad', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['舆论', 'n', 'BILIBILI', 1],
#  ['叭', 'o', 'BILIBILI', 1],
#  ['建议', 'n', 'BILIBILI', 1],
#  ['去', 'v', 'BILIBILI', 1],
#  ['看看', 'v', 'BILIBILI', 1],
#  ['《', 'x', 'BILIBILI', 1],
#  ['世界博览', 'n', 'BILIBILI', 1],
#  ['》', 'x', 'BILIBILI', 1],
#  ['中华人民共和国外交部', 'nt', 'BILIBILI', 1],
#  ['十月', 't', 'BILIBILI', 1],
#  ['三十', 'm', 'BILIBILI', 1],
#  ['号', 'm', 'BILIBILI', 1],
#  ['发文', 'n', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['内容', 'n', 'BILIBILI', 1],
#  ['哦', 'zg', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['永远', 'd', 'BILIBILI', 1],
#  ['叫', 'v', 'BILIBILI', 1],
#  ['不醒', 'v', 'BILIBILI', 1],
#  ['您们', 'r', 'BILIBILI', 1],
#  ['这些', 'r', 'BILIBILI', 1],
#  ['带有', 'v', 'BILIBILI', 1],
#  ['偏见', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['人', 'n', 'BILIBILI', 1],
#  ['[', 'x', 'BILIBILI', 1],
#  ['微笑', 'vn', 'BILIBILI', 1],
#  [']', 'x', 'BILIBILI', 1],
#  ['“', 'x', 'BILIBILI', 1],
#  ['我们', 'r', 'BILIBILI', 1],
#  ['现在', 't', 'BILIBILI', 1],
#  ['做', 'v', 'BILIBILI', 1],
#  ['的', 'uj', 'BILIBILI', 1],
#  ['事', 'n', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['以后', 'f', 'BILIBILI', 1],
#  ['会', 'v', 'BILIBILI', 1],
#  ['不会', 'v', 'BILIBILI', 1],
#  ['有人', 'r', 'BILIBILI', 1],
#  ['记得', 'v', 'BILIBILI', 1],
#  ['”', 'x', 'BILIBILI', 1],
#  ['\n', 'x', 'BILIBILI', 1],
#  ['山河', 'ns', 'BILIBILI', 1],
#  ['无恙', 'z', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['国泰民安', 'nz', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['晚辈', 'n', 'BILIBILI', 1],
#  ['叩谢', 'v', 'BILIBILI', 1],
#  ['且', 'zg', 'BILIBILI', 1],
#  ['铭记', 'n', 'BILIBILI', 1],
#  ['于', 'p', 'BILIBILI', 1],
#  ['心', 's', 'BILIBILI', 1],
#  ['！', 'x', 'BILIBILI', 1],
#  ['b', 'eng', 'BILIBILI', 1],
#  ['站里', 's', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['唯唯诺诺', 'l', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['网易', 'n', 'BILIBILI', 1],
#  ['云', 'ns', 'BILIBILI', 1],
#  ['评论', 'n', 'BILIBILI', 1],
#  ['区', 'n', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['重拳出击', 'i', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['不愧', 'a', 'BILIBILI', 1],
#  ['是', 'v', 'BILIBILI', 1],
#  ['nt', 'eng', 'BILIBILI', 1],
#  ['粉丝', 'n', 'BILIBILI', 1],
#  ['👏', 'x', 'BILIBILI', 1],
#  ['🏻', 'x', 'BILIBILI', 1],
#  ['👏', 'x', 'BILIBILI', 1],
#  ['🏻', 'x', 'BILIBILI', 1],
#  ['仗势欺人', 'i', 'BILIBILI', 1],
#  ['，', 'x', 'BILIBILI', 1],
#  ['偷换概念', 'i', 'BILIBILI', 1],
#  ['有', 'v', 'BILIBILI', 1],
#  ['一手', 'm', 'BILIBILI', 1],
#  ['啊', 'zg', 'BILIBILI', 1],
#  ['👏', 'x', 'BILIBILI', 1],
#  ['🏻', 'x', 'BILIBILI', 1],
#  ['👏', 'x', 'BILIBILI', 1],
#  ['🏻', 'x', 'BILIBILI', 1],
#  ['好家伙', 'e', 'BILIBILI', 1],
#  ['我', 'r', 'BILIBILI', 1],
#  ['TM', 'eng', 'BILIBILI', 1],
#  ['直接', 'ad', 'BILIBILI', 1],
#  ['好家伙', 'e', 'BILIBILI', 1],
#  ...]

# %%
# 단일 데이터프레임 구조로 변환
분석통합 = pd.DataFrame(저장공간)

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#                 0    1         2  3
# 0              立场    n  BILIBILI  1
# 1              不同    a  BILIBILI  1
# 2               ，    x  BILIBILI  1
# 3              他们    r  BILIBILI  1
# 4               也    d  BILIBILI  1
# ...           ...  ...       ... ..
# 128390          ‪    x  BILIBILI  1
# 128391          ❗    x  BILIBILI  1
# 128392  ATTENTION  eng  BILIBILI  1
# 128393          ❗    x  BILIBILI  1
# 128394          ‬    x  BILIBILI  1
#
# [128395 rows x 4 columns]

# %%
# "분석통합" 변수의 컬럼(열) 이름 변경
분석통합.columns = ["형태소", "품사", "분류", "카운트"]

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#               형태소   품사        분류  카운트
# 0              立场    n  BILIBILI    1
# 1              不同    a  BILIBILI    1
# 2               ，    x  BILIBILI    1
# 3              他们    r  BILIBILI    1
# 4               也    d  BILIBILI    1
# ...           ...  ...       ...  ...
# 128390          ‪    x  BILIBILI    1
# 128391          ❗    x  BILIBILI    1
# 128392  ATTENTION  eng  BILIBILI    1
# 128393          ❗    x  BILIBILI    1
# 128394          ‬    x  BILIBILI    1
#
# [128395 rows x 4 columns]

# %%
# "분석통합" 변수의 내용을 형태소, 품사, 분류가 같은 것을 합치고, 카운트의 총합을 구해서 "그룹통합" 변수에 저장한다.
그룹통합 = 분석통합.groupby(['형태소', '품사', "분류"])['카운트'].sum()

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
# 형태소   품사  분류
# \n    x   BILIBILI    1583
# \r    x   BILIBILI       2
# \r\n  x   BILIBILI       1
#       x   BILIBILI    2617
# !     x   BILIBILI     298
#                       ...
# 🥳     x   BILIBILI       1
# 🦆     x   BILIBILI       1
# 🦐     x   BILIBILI       2
# 🧣     x   BILIBILI       4
# 𣎴     x   BILIBILI       1
# Name: 카운트, Length: 12530, dtype: int64

# %%
# "그룹통합" 변수의 내용을 데이터프레임 형식으로 변환해서 "그룹통합" 변수에 저장한다.
그룹통합 = pd.DataFrame(그룹통합)

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
#                    카운트
# 형태소  품사 분류
# \n   x  BILIBILI  1583
# \r   x  BILIBILI     2
# \r\n x  BILIBILI     1
#      x  BILIBILI  2617
# !    x  BILIBILI   298
# ...                ...
# 🥳    x  BILIBILI     1
# 🦆    x  BILIBILI     1
# 🦐    x  BILIBILI     2
# 🧣    x  BILIBILI     4
# 𣎴    x  BILIBILI     1
#
# [12530 rows x 1 columns]

# %%
# "그룹통합" 변수의 내용을 "형태소분석결과.csv" 파일로 저장한다.
# header는 컬럼(열) 정보의 포함 여부이다.
# encoding은 문자코드를 선택하는 것이다. python에서는 기본적으로 utf-8(유니코드)를 사용한다.

그룹통합.to_csv('지에바.csv', header='true', encoding='utf-8-sig')
